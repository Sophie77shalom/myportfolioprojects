# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
file_path = "/kaggle/input/marvel-wikia-dataset/marvel-wikia-data.csv"
my_data = pd.read_csv(file_path)
my_data
# Out:
#        page_id                                 name  \
# 0         1678            Spider-Man (Peter Parker)
# 1         7139      Captain America (Steven Rogers)
# 2        64786  Wolverine (James \"Logan\" Howlett)
# 3         1868    Iron Man (Anthony \"Tony\" Stark)
# 4         2460                  Thor (Thor Odinson)
# ...        ...                                  ...
# 16371   657508                   Ru'ach (Earth-616)
# 16372   665474      Thane (Thanos' son) (Earth-616)
# 16373   695217        Tinkerer (Skrull) (Earth-616)
# 16374   708811       TK421 (Spiderling) (Earth-616)
# 16375   673702                Yologarch (Earth-616)
#
#                                        urlslug                ID  \
# 0                  \/Spider-Man_(Peter_Parker)   Secret Identity
# 1            \/Captain_America_(Steven_Rogers)   Public Identity
# 2      \/Wolverine_(James_%22Logan%22_Howlett)   Public Identity
# 3        \/Iron_Man_(Anthony_%22Tony%22_Stark)   Public Identity
# ...

# %% [markdown]
# Line chart showing evolution in comic books.

# %%
#line chart
sns.lineplot(data=my_data)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: >

# %%
plt.figure(figsize=(16, 8))
plt.title("Comic Books")
sns.lineplot(data=my_data)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: title={'center': 'Comic Books'}>

# %%
list(my_data.columns)
# Out:
# ['page_id',
#  'name',
#  'urlslug',
#  'ID',
#  'ALIGN',
#  'EYE',
#  'HAIR',
#  'SEX',
#  'GSM',
#  'ALIVE',
#  'APPEARANCES',
#  'FIRST APPEARANCE',
#  'Year']

# %%
# Set the width and height of the figure
plt.figure(figsize=(14,6))

# Add title
plt.title("Comic Books")

# Line chart showing daily global streams of 'Shape of You'
sns.lineplot(data=my_data['EYE'], label="EYE")

# Line chart showing daily global streams of 'Despacito'
sns.lineplot(data=my_data['page_id'], label="page_id")

# Add label for horizontal axis
plt.xlabel("Year")
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# Bar Charts and Heatmaps

# %%
# Bar chart
# Set the width and height of the figure
plt.figure(figsize=(10,6))

# Add title
plt.title("Comic Books")

# Bar chart showing average arrival delay for Spirit Airlines flights by month
sns.barplot(x=my_data.index, y=my_data['EYE'])

# Add label for vertical axis
plt.ylabel("Year")
# Out:
# Text(0, 0.5, 'Year')

# %%
# Bar chart
# Set the width and height of the figure
plt.figure(figsize=(10,6))

# Add title
plt.title("Comic Books")

# Bar chart showing average arrival delay for Spirit Airlines flights by month
sns.barplot(x=my_data.index, y=my_data['page_id'])

# Add label for vertical axis
#plt.ylabel("Year")
# Out:
# <Axes: title={'center': 'Comic Books'}, ylabel='page_id'>

# %%
#heatmap
# Select relevant columns and fill missing values
heatmap_data = my_data.pivot_table(
    index='page_id',
    columns='ALIGN',  # You can also try 'SEX' or other categorical columns
    values='APPEARANCES',
    aggfunc='sum'
).fillna(0)  # Replace NaN with 0

# Plot the heatmap
plt.figure(figsize=(14, 7))
sns.heatmap(heatmap_data, annot=True, fmt=".1f", cmap="coolwarm")

# Add labels and title
plt.title("Appearances by Alignment and Page ID")
plt.xlabel("Alignment")
plt.ylabel("Page ID")
plt.show()

# %% [markdown]
# Scatter Plots

# %%
#Scatter Plot
sns.scatterplot(x=my_data['Year'], y=my_data['page_id'])
# Out:
# <Axes: xlabel='Year', ylabel='page_id'>

# %%
#regression line

sns.regplot(x=my_data['Year'], y=my_data['page_id'])
# Out:
# <Axes: xlabel='Year', ylabel='page_id'>

# %%
#Color-coded scatter plots

sns.scatterplot(x=my_data['Year'], y=my_data['APPEARANCES'], hue=my_data['page_id'])
# Out:
# <Axes: xlabel='Year', ylabel='APPEARANCES'>

# %%
#lmplot
sns.lmplot(x='Year', y='page_id', hue='Year', data=my_data)

# %%
#swarmplot
sns.swarmplot(x=my_data['Year'],
              y=my_data['APPEARANCES'])
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# Histogram

# %%
# Histogram 
sns.histplot(my_data['Year'])
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Year', ylabel='Count'>

# %% [markdown]
# kernel density estimate (KDE) plot

# %%
#kdeplot
sns.kdeplot(data=my_data['Year'], shade=True)
# Out:
# /tmp/ipykernel_17/1515543436.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=my_data['Year'], shade=True)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Year', ylabel='Density'>

# %%
# 2D KDE plot
sns.jointplot(x=my_data['Year'], y=my_data['page_id'], kind="kde")
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %% [markdown]
# Color-coded plots

# %%
# Histograms for each species
sns.histplot(data=my_data, x='Year', hue='Year')

# Add title
plt.title("Comic Books")
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
# KDE plots for each species
sns.kdeplot(data=my_data, x='page_id', hue='Year', shade=True)

# Add title
plt.title("Comic Books")
# Out:
# /tmp/ipykernel_17/3382462375.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=my_data, x='page_id', hue='Year', shade=True)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# Text(0.5, 1.0, 'Comic Books')
